# %% [markdown]
# ### Import Library

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split ## 訓練、測試切割
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score,mean_absolute_percentage_error,mean_squared_error
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### Data Preprocessing

# %%
house_data = pd.read_csv("./Boston_Housing/HousingData.csv", header= None, names=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV'])
house_data = house_data.drop(0,axis=0)
#刪除重複的值
print("原始比數：",house_data.shape)
house_data.drop_duplicates(inplace=True)
house_data = house_data.sort_index(axis=0)
print("刪除重複的值後：",house_data.shape)

# 判斷是否還有空值
house_data.isnull().sum(axis=0)
# Out:
# 原始比數： (506, 14)
# 刪除重複的值後： (506, 14)
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
#將把'LSTAT'中無法轉換為數字的值設為 NaN
house_data['CRIM'] = pd.to_numeric(house_data['CRIM'], errors='coerce')
house_data['ZN'] = pd.to_numeric(house_data['ZN'], errors='coerce')
house_data['INDUS'] = pd.to_numeric(house_data['INDUS'], errors='coerce')
house_data['CHAS'] = pd.to_numeric(house_data['CHAS'], errors='coerce')
house_data['AGE'] = pd.to_numeric(house_data['AGE'], errors='coerce')
house_data['LSTAT'] = pd.to_numeric(house_data['LSTAT'], errors='coerce')

#刪除問號的值(取平均數)
house_data['CRIM'].fillna(house_data['CRIM'].mean(), inplace=True)
house_data['ZN'].fillna(house_data['ZN'].mean(), inplace=True)
house_data['INDUS'].fillna(house_data['INDUS'].mean(), inplace=True)
house_data['CHAS'].fillna(house_data['CHAS'].mean(), inplace=True)
house_data['AGE'].fillna(house_data['AGE'].mean(), inplace=True)
house_data['LSTAT'].fillna(house_data['LSTAT'].mean(), inplace=True)

# %%
house_data.isnull().sum(axis=0)
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
## 數值屬性做Normalization(z-score)
numerical_columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']
scaler = preprocessing.StandardScaler()
house_data[numerical_columns] = scaler.fit_transform(house_data[numerical_columns])
house_data
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM           AGE  \
# 1   -0.422328  0.296443 -1.311010 -0.279851 -0.144217  0.413672 -1.210593e-01
# 2   -0.419870 -0.489639 -0.599771 -0.279851 -0.740262  0.194274  3.787156e-01
# 3   -0.419872 -0.489639 -0.599771 -0.279851 -0.740262  1.282714 -2.706270e-01
# 4   -0.419277 -0.489639 -1.330435 -0.279851 -0.835284  1.016303 -8.287698e-01
# 5   -0.414981 -0.489639 -1.330435 -0.279851 -0.835284  1.228577 -5.223385e-01
# ..        ...       ...       ...       ...       ...       ...           ...
# 502 -0.415733 -0.489639  0.126411 -0.279851  0.158124  0.439316  2.121240e-02
# 503 -0.417766 -0.489639  0.126411 -0.279851  0.158124 -0.234548  2.984598e-01
# 504 -0.415952 -0.489639  0.126411 -0.279851  0.158124  0.984960  8.201227e-01
# 505 -0.410232 -0.489639  0.126411 -0.279851  0.158124  0.725672  7.581068e-01
# 506 -0.417515 -0.489639  0.126411 -0.279851  0.158124 -0.362767  5.184109e-16
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT  MEDV
# 1    0.140214 -0.982843 -0.666608 -1.459000  0.441052 -1.104146    24
# 2    0.557160 -0.867883 -0.987329 -0.303094  0.441052 -0.510353  21.6
# 3    0.557160 -0.867883 -0.987329 -0.303094  0.396427 -1.239748  34.7
# 4    1.077737 -0.752922 -1.106115  0.113032  0.416163 -1.395333  33.4
# 5    1.077737 -0.752922 -1.106115  0.113032  0.441052  0.000000  36.2
# ..        ...       ...       ...       ...       ...       ...   ...
# 502 -0.625796 -0.982843 -0.803212  1.176466  0.387217  0.000000  22.4
# 503 -0.716639 -0.982843 -0.803212  1.176466  0.441052 -0.518917  20.6
# 504 -0.773684 -0.982843 -0.803212  1.176466  0.441052 -1.009938  23.9
# 505 -0.668437 -0.982843 -0.803212  1.176466  0.403225 -0.890038    22
# 506 -0.613246 -0.982843 -0.803212  1.176466  0.441052 -0.690204  11.9
#
# [506 rows x 14 columns]

# %%
house_data.to_excel('house_data.xlsx')

# %% [markdown]
# ### Dataset Splitting

# %%
import xgboost as xgb
house_process=[]
for i in house_data["MEDV"].ravel():
    house_process.append(float(i))
house_data["MEDV"]=house_process

X = house_data.drop("MEDV",axis=1)
y = house_data["MEDV"]
## 7:3(215) / 8:2(6984)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3, random_state=216)

k_scores=[]
train_performance=[]
test_performance=[]
for k in range(1,21):
    ## max_depth、eta、gamma
    # xgbrModel=xgb.XGBRegressor(booster='gblinear',verbosity=1)
    xgbrModel=xgb.XGBRegressor(booster='gbtree',max_depth=k,eta=0.2,gamma=10)
    xgbrModel.fit(X_train,y_train)
    pred=xgbrModel.predict(X_train)
    train_performance.append(np.sqrt(mean_squared_error(y_train,pred)))
    scores = cross_val_score(xgbrModel,X_train,y_train,cv=5,scoring=None,n_jobs=1,verbose=0)
    print(scores)
    print(scores.mean())
    k_scores.append(scores.mean())
    print(f'-------------------------------------------')

    ## 預測
    y_pred=xgbrModel.predict(X_test)
    #calculate rmse
    error_rmse = np.sqrt(mean_squared_error(y_test,y_pred)) 
    print('RMSE:', round(error_rmse,3))
    #calculate mape
    error_mape = mean_absolute_percentage_error(y_test,y_pred) 
    print(f'MAPE:{round((error_mape*100),2)}%')
    #calculate r squared
    error_r2 = r2_score(y_test,y_pred) 
    print('r_squared_value:', round(error_r2,3))
    test_performance.append(np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# [0.74183596 0.67235079 0.8901095  0.71973926 0.79111659]
# 0.763030420104779
# -------------------------------------------
# RMSE: 3.649
# MAPE:11.28%
# r_squared_value: 0.861
# [0.71337804 0.6762531  0.90352681 0.7464545  0.79351043]
# 0.7666245765924622
# -------------------------------------------
# RMSE: 3.153
# MAPE:10.79%
# r_squared_value: 0.896
# [0.74474195 0.66799867 0.90134445 0.7075426  0.75151625]
# 0.7546287837093886
# -------------------------------------------
# RMSE: 2.891
# MAPE:10.25%
# r_squared_value: 0.913
# [0.73466872 0.6638002  0.88160553 0.68436393 0.73357911]
# 0.7396034983315062
# -------------------------------------------
# RMSE: 2.86
# MAPE:9.91%
# r_squared_value: 0.915
# [0.72004867 0.69511578 0.87741555 0.66656502 0.69027538]
# 0.7298840802796804
# -------------------------------------------
# RMSE: 2.823
# MAPE:10.06%
# r_squared_value: 0.917
# [0.7141583  0.67406185 0.87738927 0.6695868  0.69956787]
# 0.7269528197223981
# -------------------------------------------
# RMSE: 2.891
# MAPE:10.22%
# r_squared_value: 0.913
# [0.71324446 0.67027431 0.87971299 0.66252294 0.68897037]
# 0.7229450126550117
# -------------------------------------------
# RMSE: 2.884
# MAPE:9.84%
# r_squared_value: 0.913
# [0.71404873 0.64877771 0.87698818 0.6579143  0.68996012]
# 0.7175378092292712
# -------------------------------------------
# RMSE: 2.827
# MAPE:9.98%
# r_squared_value: 0.916
# [0.69866088 0.64350561 0.88161711 0.66718857 0.68705038]
# 0.7156045080840243
# -------------------------------------------
# RMSE: 2.869
# MAPE:10.27%
# r_squared_value: 0.914
# [0.70860943 0.65487511 0.88288658 0.67500106 0.68563424]
# 0.7214012868380679
# -------------------------------------------
# RMSE: 2.851
# MAPE:10.05%
# r_squared_value: 0.915
# [0.70860943 0.65601622 0.88295034 0.66942884 0.70111555]
# 0.723624077774398
# -------------------------------------------
# RMSE: 2.803
# MAPE:10.01%
# r_squared_value: 0.918
# [0.70860943 0.65601622 0.88222127 0.66746754 0.68983523]
# 0.7208299403626661
# -------------------------------------------
# RMSE: 2.803
# MAPE:10.01%
# r_squared_value: 0.918
# [0.70860943 0.65601622 0.88222127 0.67137489 0.68983523]
# 0.7216114098746003
# -------------------------------------------
# RMSE: 2.803
# MAPE:10.01%
# r_squared_value: 0.918
# [0.70860943 0.65601622 0.88311985 0.67137489 0.68983523]
# 0.7217911253956917
# -------------------------------------------
# RMSE: 2.803
# MAPE:10.01%
# r_squared_value: 0.918
# [0.70860943 0.64963132 0.88250752 0.67137489 0.68983523]
# 0.7203916785622322
# -------------------------------------------
# RMSE: 2.803
# MAPE:10.01%
# r_squared_value: 0.918
# [0.70860943 0.64963132 0.88250752 0.67137489 0.68983523]
# 0.7203916785622322
# -------------------------------------------
# RMSE: 2.803
# MAPE:10.01%
# r_squared_value: 0.918
# [0.70860943 0.64963132 0.88250752 0.67137489 0.68983523]
# 0.7203916785622322
# -------------------------------------------
# RMSE: 2.803
# MAPE:10.01%
# r_squared_value: 0.918
# [0.70860943 0.64963132 0.88250752 0.67137489 0.68983523]
# 0.7203916785622322
# -------------------------------------------
# RMSE: 2.803
# MAPE:10.01%
# r_squared_value: 0.918
# [0.70860943 0.64963132 0.88250752 0.67137489 0.68983523]
# 0.7203916785622322
# -------------------------------------------
# RMSE: 2.803
# MAPE:10.01%
# r_squared_value: 0.918
# [0.70860943 0.64963132 0.88250752 0.67137489 0.68983523]
# 0.7203916785622322
# -------------------------------------------
# RMSE: 2.803
# MAPE:10.01%
# r_squared_value: 0.918

# %%
test_performance
# Out:
# [3.6490259816872377,
#  3.1529963246857626,
#  2.8908068959558086,
#  2.8603859498691007,
#  2.8230171190516717,
#  2.890995999023552,
#  2.883510373530629,
#  2.8271804169560695,
#  2.8690295810359596,
#  2.850735805118133,
#  2.8032184774982665,
#  2.8032184774982665,
#  2.8032184774982665,
#  2.8032184774982665,
#  2.8032184774982665,
#  2.8032184774982665,
#  2.8032184774982665,
#  2.8032184774982665,
#  2.8032184774982665,
#  2.8032184774982665]

# %%
train = train_performance
test = test_performance
plt.plot(train, label='train_performance',color='green')
plt.plot(test, label='test_performance',color='blue')
plt.ylabel("RMSE")
plt.xlabel("tree_max_depth")
plt.title("max_depth_and_performance")
plt.xlim([0, 21])
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.plot(range(1,21),k_scores)
plt.xlabel('max_depth of XGBoost')
plt.ylabel('Average of Cross-Validated Accuracy')
plt.show()

# %%
xgbrModel.fit(X_train,y_train)
print(f'training_performance: {round(xgbrModel.score(X_train, y_train),3)}')
# Out:
# training_performance: 0.984

# %%
import xgboost as xgb
house_process=[]
for i in house_data["MEDV"].ravel():
    house_process.append(float(i))
house_data["MEDV"]=house_process

X = house_data.drop("MEDV",axis=1)
y = house_data["MEDV"]
## 7:3(215) / 8:2(6984)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3, random_state=216)

## max_depth、eta、gamma
# xgbrModel=xgb.XGBRegressor(booster='gblinear',verbosity=1)
xgbrModel=xgb.XGBRegressor(booster='gbtree',max_depth=2,eta=0.2)
xgbrModel.fit(X_train,y_train)
scores = cross_val_score(xgbrModel,X_train,y_train,cv=5,scoring=None,n_jobs=1,verbose=0)
print(scores)
print(scores.mean())
# Out:
# [0.71312685 0.68638736 0.90789446 0.75768793 0.78952769]
# 0.7709248598201817

# %% [markdown]
# ### Evaluation

# %%
## 預測
y_pred=xgbrModel.predict(X_test)
#calculate rmse
error_rmse = np.sqrt(mean_squared_error(y_test,y_pred)) 
print('RMSE:', round(error_rmse,3))
#calculate mape
error_mape = mean_absolute_percentage_error(y_test,y_pred) 
print(f'MAPE:{round((error_mape*100),2)}%')
#calculate r squared
error_r2 = r2_score(y_test,y_pred) 
print('r_squared_value:', round(error_r2,3))
# Out:
# RMSE: 3.114
# MAPE:10.77%
# r_squared_value: 0.899

# %%
import xgboost as xgb
X = house_data.drop("MEDV",axis=1)
y = house_data["MEDV"]

score_max=[]
for i in range(200,10000):
    ## 7:3(215) / 8:2(6984)
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3, random_state=i)
    xgbrModel=xgb.XGBRegressor()
    xgbrModel.fit(X_train,y_train)
    print(f'training_accuracy: {round(xgbrModel.score(X_train, y_train),3)}') 

    ## 預測
    y_pred=xgbrModel.predict(X_test)
    #calculate rmse
    error_rmse = np.sqrt(mean_squared_error(y_test,y_pred)) 
    print('RMSE:', round(error_rmse,3))
    #calculate mape
    error_mape = mean_absolute_percentage_error(y_test,y_pred) 
    print('MAPE:', round(error_mape,3))
    #calculate r squared
    error_r2 = r2_score(y_test,y_pred) 
    print('r_squared_value:', round(error_r2,3))
    score_max.append(round(error_r2,3))
    print('--------------------------')
print(f'最佳的績效的random_state:{np.argmax(score_max)}')
print('==================================================')
# Out:
# training_accuracy: 1.0
# RMSE: 3.727
# MAPE: 0.125
# r_squared_value: 0.873
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.472
# MAPE: 0.136
# r_squared_value: 0.837
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.548
# MAPE: 0.122
# r_squared_value: 0.869
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.643
# MAPE: 0.117
# r_squared_value: 0.838
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.176
# MAPE: 0.109
# r_squared_value: 0.868
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.869
# MAPE: 0.118
# r_squared_value: 0.879
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.244
# MAPE: 0.125
# r_squared_value: 0.781
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.425
# MAPE: 0.125
# r_squared_value: 0.84
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.569
# MAPE: 0.117
# r_squared_value: 0.86
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.166
# MAPE: 0.114
# r_squared_value: 0.892
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.517
# MAPE: 0.124
# r_squared_value: 0.859
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.394
# MAPE: 0.112
# r_squared_value: 0.862
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.077
# MAPE: 0.111
# r_squared_value: 0.897
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.751
# MAPE: 0.12
# r_squared_value: 0.904
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.324
# MAPE: 0.123
# r_squared_value: 0.87
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.547
# MAPE: 0.126
# r_squared_value: 0.87
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.981
# MAPE: 0.107
# r_squared_value: 0.907
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.162
# MAPE: 0.109
# r_squared_value: 0.888
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.732
# MAPE: 0.102
# r_squared_value: 0.902
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.241
# MAPE: 0.11
# r_squared_value: 0.872
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.173
# MAPE: 0.11
# r_squared_value: 0.877
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.864
# MAPE: 0.106
# r_squared_value: 0.902
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.032
# MAPE: 0.108
# r_squared_value: 0.903
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.083
# MAPE: 0.117
# r_squared_value: 0.903
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.787
# MAPE: 0.118
# r_squared_value: 0.845
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.207
# MAPE: 0.112
# r_squared_value: 0.86
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.826
# MAPE: 0.103
# r_squared_value: 0.884
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.973
# MAPE: 0.123
# r_squared_value: 0.842
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.251
# MAPE: 0.122
# r_squared_value: 0.904
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.355
# MAPE: 0.116
# r_squared_value: 0.86
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.931
# MAPE: 0.138
# r_squared_value: 0.84
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.266
# MAPE: 0.12
# r_squared_value: 0.858
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.686
# MAPE: 0.108
# r_squared_value: 0.828
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.147
# MAPE: 0.124
# r_squared_value: 0.883
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.879
# MAPE: 0.137
# r_squared_value: 0.839
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.578
# MAPE: 0.129
# r_squared_value: 0.838
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.294
# MAPE: 0.12
# r_squared_value: 0.879
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.459
# MAPE: 0.142
# r_squared_value: 0.883
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.18
# MAPE: 0.116
# r_squared_value: 0.894
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.461
# MAPE: 0.114
# r_squared_value: 0.762
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.799
# MAPE: 0.128
# r_squared_value: 0.834
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.205
# MAPE: 0.132
# r_squared_value: 0.768
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.861
# MAPE: 0.12
# r_squared_value: 0.88
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.905
# MAPE: 0.115
# r_squared_value: 0.902
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.156
# MAPE: 0.127
# r_squared_value: 0.883
# --------------------------
# training_accuracy: 1.0
# RMSE: 5.018
# MAPE: 0.133
# r_squared_value: 0.732
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.799
# MAPE: 0.11
# r_squared_value: 0.913
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.227
# MAPE: 0.111
# r_squared_value: 0.889
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.331
# MAPE: 0.109
# r_squared_value: 0.829
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.093
# MAPE: 0.125
# r_squared_value: 0.805
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.892
# MAPE: 0.115
# r_squared_value: 0.868
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.383
# MAPE: 0.113
# r_squared_value: 0.858
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.697
# MAPE: 0.116
# r_squared_value: 0.854
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.308
# MAPE: 0.13
# r_squared_value: 0.869
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.359
# MAPE: 0.122
# r_squared_value: 0.875
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.075
# MAPE: 0.108
# r_squared_value: 0.888
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.091
# MAPE: 0.106
# r_squared_value: 0.903
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.674
# MAPE: 0.127
# r_squared_value: 0.848
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.292
# MAPE: 0.143
# r_squared_value: 0.722
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.412
# MAPE: 0.116
# r_squared_value: 0.862
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.429
# MAPE: 0.128
# r_squared_value: 0.875
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.267
# MAPE: 0.139
# r_squared_value: 0.802
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.804
# MAPE: 0.109
# r_squared_value: 0.899
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.432
# MAPE: 0.128
# r_squared_value: 0.877
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.199
# MAPE: 0.115
# r_squared_value: 0.88
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.05
# MAPE: 0.107
# r_squared_value: 0.902
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.779
# MAPE: 0.126
# r_squared_value: 0.793
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.395
# MAPE: 0.123
# r_squared_value: 0.829
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.38
# MAPE: 0.111
# r_squared_value: 0.849
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.959
# MAPE: 0.104
# r_squared_value: 0.859
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.779
# MAPE: 0.145
# r_squared_value: 0.759
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.767
# MAPE: 0.139
# r_squared_value: 0.792
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.698
# MAPE: 0.129
# r_squared_value: 0.838
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.255
# MAPE: 0.116
# r_squared_value: 0.793
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.994
# MAPE: 0.098
# r_squared_value: 0.859
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.831
# MAPE: 0.13
# r_squared_value: 0.825
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.209
# MAPE: 0.121
# r_squared_value: 0.861
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.784
# MAPE: 0.102
# r_squared_value: 0.891
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.422
# MAPE: 0.119
# r_squared_value: 0.845
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.154
# MAPE: 0.108
# r_squared_value: 0.885
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.664
# MAPE: 0.12
# r_squared_value: 0.802
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.43
# MAPE: 0.144
# r_squared_value: 0.794
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.753
# MAPE: 0.124
# r_squared_value: 0.768
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.548
# MAPE: 0.135
# r_squared_value: 0.854
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.002
# MAPE: 0.126
# r_squared_value: 0.812
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.84
# MAPE: 0.127
# r_squared_value: 0.813
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.509
# MAPE: 0.119
# r_squared_value: 0.867
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.511
# MAPE: 0.12
# r_squared_value: 0.861
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.626
# MAPE: 0.126
# r_squared_value: 0.844
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.45
# MAPE: 0.127
# r_squared_value: 0.852
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.79
# MAPE: 0.126
# r_squared_value: 0.811
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.318
# MAPE: 0.138
# r_squared_value: 0.827
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.234
# MAPE: 0.125
# r_squared_value: 0.877
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.713
# MAPE: 0.121
# r_squared_value: 0.773
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.848
# MAPE: 0.127
# r_squared_value: 0.758
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.104
# MAPE: 0.124
# r_squared_value: 0.898
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.435
# MAPE: 0.118
# r_squared_value: 0.848
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.232
# MAPE: 0.102
# r_squared_value: 0.871
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.565
# MAPE: 0.126
# r_squared_value: 0.794
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.472
# MAPE: 0.128
# r_squared_value: 0.774
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.778
# MAPE: 0.109
# r_squared_value: 0.908
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.68
# MAPE: 0.128
# r_squared_value: 0.814
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.888
# MAPE: 0.1
# r_squared_value: 0.886
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.459
# MAPE: 0.115
# r_squared_value: 0.849
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.084
# MAPE: 0.112
# r_squared_value: 0.875
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.151
# MAPE: 0.111
# r_squared_value: 0.893
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.21
# MAPE: 0.098
# r_squared_value: 0.874
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.129
# MAPE: 0.127
# r_squared_value: 0.862
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.444
# MAPE: 0.099
# r_squared_value: 0.85
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.848
# MAPE: 0.111
# r_squared_value: 0.892
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.424
# MAPE: 0.112
# r_squared_value: 0.834
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.923
# MAPE: 0.131
# r_squared_value: 0.785
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.916
# MAPE: 0.115
# r_squared_value: 0.898
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.684
# MAPE: 0.116
# r_squared_value: 0.863
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.582
# MAPE: 0.122
# r_squared_value: 0.848
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.289
# MAPE: 0.114
# r_squared_value: 0.885
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.302
# MAPE: 0.12
# r_squared_value: 0.881
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.279
# MAPE: 0.112
# r_squared_value: 0.876
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.622
# MAPE: 0.111
# r_squared_value: 0.839
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.674
# MAPE: 0.11
# r_squared_value: 0.893
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.183
# MAPE: 0.11
# r_squared_value: 0.86
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.364
# MAPE: 0.128
# r_squared_value: 0.859
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.92
# MAPE: 0.115
# r_squared_value: 0.885
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.243
# MAPE: 0.123
# r_squared_value: 0.862
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.02
# MAPE: 0.112
# r_squared_value: 0.894
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.438
# MAPE: 0.129
# r_squared_value: 0.865
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.362
# MAPE: 0.122
# r_squared_value: 0.828
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.436
# MAPE: 0.123
# r_squared_value: 0.86
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.023
# MAPE: 0.114
# r_squared_value: 0.881
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.831
# MAPE: 0.108
# r_squared_value: 0.899
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.273
# MAPE: 0.117
# r_squared_value: 0.778
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.495
# MAPE: 0.116
# r_squared_value: 0.839
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.256
# MAPE: 0.114
# r_squared_value: 0.863
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.229
# MAPE: 0.111
# r_squared_value: 0.875
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.333
# MAPE: 0.113
# r_squared_value: 0.79
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.23
# MAPE: 0.128
# r_squared_value: 0.904
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.104
# MAPE: 0.114
# r_squared_value: 0.889
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.429
# MAPE: 0.117
# r_squared_value: 0.791
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.064
# MAPE: 0.109
# r_squared_value: 0.897
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.032
# MAPE: 0.143
# r_squared_value: 0.8
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.464
# MAPE: 0.111
# r_squared_value: 0.844
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.201
# MAPE: 0.121
# r_squared_value: 0.873
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.333
# MAPE: 0.124
# r_squared_value: 0.873
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.28
# MAPE: 0.116
# r_squared_value: 0.908
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.023
# MAPE: 0.106
# r_squared_value: 0.878
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.756
# MAPE: 0.104
# r_squared_value: 0.911
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.935
# MAPE: 0.119
# r_squared_value: 0.904
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.079
# MAPE: 0.127
# r_squared_value: 0.865
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.069
# MAPE: 0.114
# r_squared_value: 0.792
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.277
# MAPE: 0.109
# r_squared_value: 0.86
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.802
# MAPE: 0.105
# r_squared_value: 0.916
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.524
# MAPE: 0.134
# r_squared_value: 0.852
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.606
# MAPE: 0.128
# r_squared_value: 0.736
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.764
# MAPE: 0.136
# r_squared_value: 0.851
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.272
# MAPE: 0.117
# r_squared_value: 0.897
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.328
# MAPE: 0.113
# r_squared_value: 0.883
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.232
# MAPE: 0.114
# r_squared_value: 0.879
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.327
# MAPE: 0.113
# r_squared_value: 0.883
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.857
# MAPE: 0.111
# r_squared_value: 0.824
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.153
# MAPE: 0.109
# r_squared_value: 0.872
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.602
# MAPE: 0.104
# r_squared_value: 0.927
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.886
# MAPE: 0.109
# r_squared_value: 0.896
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.398
# MAPE: 0.113
# r_squared_value: 0.781
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.211
# MAPE: 0.117
# r_squared_value: 0.86
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.138
# MAPE: 0.133
# r_squared_value: 0.893
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.863
# MAPE: 0.115
# r_squared_value: 0.834
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.651
# MAPE: 0.129
# r_squared_value: 0.743
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.752
# MAPE: 0.129
# r_squared_value: 0.799
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.424
# MAPE: 0.106
# r_squared_value: 0.887
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.841
# MAPE: 0.114
# r_squared_value: 0.835
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.95
# MAPE: 0.132
# r_squared_value: 0.851
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.281
# MAPE: 0.107
# r_squared_value: 0.797
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.994
# MAPE: 0.109
# r_squared_value: 0.895
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.757
# MAPE: 0.114
# r_squared_value: 0.904
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.153
# MAPE: 0.11
# r_squared_value: 0.881
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.232
# MAPE: 0.114
# r_squared_value: 0.895
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.996
# MAPE: 0.127
# r_squared_value: 0.849
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.001
# MAPE: 0.119
# r_squared_value: 0.903
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.229
# MAPE: 0.114
# r_squared_value: 0.894
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.133
# MAPE: 0.107
# r_squared_value: 0.893
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.27
# MAPE: 0.128
# r_squared_value: 0.835
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.672
# MAPE: 0.11
# r_squared_value: 0.804
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.965
# MAPE: 0.115
# r_squared_value: 0.898
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.572
# MAPE: 0.095
# r_squared_value: 0.908
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.66
# MAPE: 0.106
# r_squared_value: 0.915
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.424
# MAPE: 0.118
# r_squared_value: 0.833
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.127
# MAPE: 0.135
# r_squared_value: 0.882
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.037
# MAPE: 0.102
# r_squared_value: 0.799
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.035
# MAPE: 0.12
# r_squared_value: 0.808
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.154
# MAPE: 0.107
# r_squared_value: 0.879
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.255
# MAPE: 0.116
# r_squared_value: 0.89
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.031
# MAPE: 0.109
# r_squared_value: 0.89
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.488
# MAPE: 0.135
# r_squared_value: 0.78
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.406
# MAPE: 0.122
# r_squared_value: 0.837
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.844
# MAPE: 0.115
# r_squared_value: 0.759
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.674
# MAPE: 0.122
# r_squared_value: 0.835
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.945
# MAPE: 0.111
# r_squared_value: 0.894
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.216
# MAPE: 0.128
# r_squared_value: 0.773
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.575
# MAPE: 0.142
# r_squared_value: 0.742
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.857
# MAPE: 0.101
# r_squared_value: 0.852
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.111
# MAPE: 0.117
# r_squared_value: 0.867
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.669
# MAPE: 0.132
# r_squared_value: 0.87
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.829
# MAPE: 0.116
# r_squared_value: 0.824
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.184
# MAPE: 0.117
# r_squared_value: 0.857
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.368
# MAPE: 0.126
# r_squared_value: 0.848
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.25
# MAPE: 0.104
# r_squared_value: 0.88
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.139
# MAPE: 0.127
# r_squared_value: 0.84
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.644
# MAPE: 0.122
# r_squared_value: 0.838
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.996
# MAPE: 0.125
# r_squared_value: 0.877
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.362
# MAPE: 0.123
# r_squared_value: 0.857
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.022
# MAPE: 0.119
# r_squared_value: 0.887
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.33
# MAPE: 0.121
# r_squared_value: 0.855
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.802
# MAPE: 0.096
# r_squared_value: 0.893
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.131
# MAPE: 0.114
# r_squared_value: 0.87
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.373
# MAPE: 0.132
# r_squared_value: 0.831
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.306
# MAPE: 0.106
# r_squared_value: 0.883
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.056
# MAPE: 0.104
# r_squared_value: 0.902
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.419
# MAPE: 0.12
# r_squared_value: 0.847
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.982
# MAPE: 0.146
# r_squared_value: 0.816
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.115
# MAPE: 0.112
# r_squared_value: 0.877
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.393
# MAPE: 0.122
# r_squared_value: 0.876
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.876
# MAPE: 0.126
# r_squared_value: 0.9
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.997
# MAPE: 0.12
# r_squared_value: 0.907
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.211
# MAPE: 0.114
# r_squared_value: 0.893
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.068
# MAPE: 0.121
# r_squared_value: 0.889
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.67
# MAPE: 0.118
# r_squared_value: 0.841
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.585
# MAPE: 0.123
# r_squared_value: 0.861
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.439
# MAPE: 0.107
# r_squared_value: 0.873
# --------------------------
# training_accuracy: 1.0
# RMSE: 5.219
# MAPE: 0.15
# r_squared_value: 0.745
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.329
# MAPE: 0.129
# r_squared_value: 0.808
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.059
# MAPE: 0.112
# r_squared_value: 0.891
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.057
# MAPE: 0.11
# r_squared_value: 0.854
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.954
# MAPE: 0.108
# r_squared_value: 0.901
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.55
# MAPE: 0.11
# r_squared_value: 0.799
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.044
# MAPE: 0.116
# r_squared_value: 0.793
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.662
# MAPE: 0.157
# r_squared_value: 0.745
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.356
# MAPE: 0.111
# r_squared_value: 0.876
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.275
# MAPE: 0.134
# r_squared_value: 0.784
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.829
# MAPE: 0.109
# r_squared_value: 0.905
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.094
# MAPE: 0.11
# r_squared_value: 0.867
# --------------------------
# training_accuracy: 1.0
# RMSE: 5.307
# MAPE: 0.133
# r_squared_value: 0.743
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.396
# MAPE: 0.121
# r_squared_value: 0.878
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.885
# MAPE: 0.137
# r_squared_value: 0.822
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.265
# MAPE: 0.126
# r_squared_value: 0.858
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.889
# MAPE: 0.114
# r_squared_value: 0.81
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.021
# MAPE: 0.104
# r_squared_value: 0.884
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.257
# MAPE: 0.129
# r_squared_value: 0.869
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.906
# MAPE: 0.122
# r_squared_value: 0.76
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.148
# MAPE: 0.11
# r_squared_value: 0.858
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.722
# MAPE: 0.121
# r_squared_value: 0.896
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.237
# MAPE: 0.113
# r_squared_value: 0.856
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.936
# MAPE: 0.106
# r_squared_value: 0.887
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.292
# MAPE: 0.132
# r_squared_value: 0.852
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.514
# MAPE: 0.094
# r_squared_value: 0.923
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.664
# MAPE: 0.112
# r_squared_value: 0.862
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.033
# MAPE: 0.122
# r_squared_value: 0.875
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.552
# MAPE: 0.105
# r_squared_value: 0.862
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.395
# MAPE: 0.134
# r_squared_value: 0.752
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.963
# MAPE: 0.122
# r_squared_value: 0.834
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.087
# MAPE: 0.14
# r_squared_value: 0.8
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.665
# MAPE: 0.12
# r_squared_value: 0.819
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.019
# MAPE: 0.116
# r_squared_value: 0.881
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.324
# MAPE: 0.13
# r_squared_value: 0.857
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.739
# MAPE: 0.111
# r_squared_value: 0.911
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.451
# MAPE: 0.133
# r_squared_value: 0.74
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.172
# MAPE: 0.12
# r_squared_value: 0.847
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.069
# MAPE: 0.109
# r_squared_value: 0.894
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.953
# MAPE: 0.124
# r_squared_value: 0.838
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.976
# MAPE: 0.119
# r_squared_value: 0.883
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.817
# MAPE: 0.108
# r_squared_value: 0.898
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.598
# MAPE: 0.124
# r_squared_value: 0.851
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.212
# MAPE: 0.109
# r_squared_value: 0.883
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.368
# MAPE: 0.123
# r_squared_value: 0.878
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.614
# MAPE: 0.111
# r_squared_value: 0.839
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.823
# MAPE: 0.132
# r_squared_value: 0.846
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.465
# MAPE: 0.131
# r_squared_value: 0.858
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.448
# MAPE: 0.119
# r_squared_value: 0.874
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.207
# MAPE: 0.116
# r_squared_value: 0.837
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.276
# MAPE: 0.096
# r_squared_value: 0.863
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.541
# MAPE: 0.113
# r_squared_value: 0.845
# --------------------------
# training_accuracy: 1.0
# RMSE: 5.006
# MAPE: 0.129
# r_squared_value: 0.79
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.888
# MAPE: 0.118
# r_squared_value: 0.834
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.69
# MAPE: 0.104
# r_squared_value: 0.899
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.1
# MAPE: 0.128
# r_squared_value: 0.817
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.83
# MAPE: 0.119
# r_squared_value: 0.836
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.756
# MAPE: 0.1
# r_squared_value: 0.897
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.958
# MAPE: 0.12
# r_squared_value: 0.778
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.581
# MAPE: 0.132
# r_squared_value: 0.852
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.21
# MAPE: 0.119
# r_squared_value: 0.886
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.164
# MAPE: 0.107
# r_squared_value: 0.879
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.054
# MAPE: 0.111
# r_squared_value: 0.89
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.768
# MAPE: 0.134
# r_squared_value: 0.809
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.361
# MAPE: 0.123
# r_squared_value: 0.869
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.12
# MAPE: 0.108
# r_squared_value: 0.89
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.508
# MAPE: 0.133
# r_squared_value: 0.849
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.011
# MAPE: 0.109
# r_squared_value: 0.889
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.049
# MAPE: 0.129
# r_squared_value: 0.833
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.74
# MAPE: 0.13
# r_squared_value: 0.854
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.352
# MAPE: 0.136
# r_squared_value: 0.814
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.076
# MAPE: 0.098
# r_squared_value: 0.877
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.294
# MAPE: 0.113
# r_squared_value: 0.825
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.295
# MAPE: 0.108
# r_squared_value: 0.836
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.234
# MAPE: 0.111
# r_squared_value: 0.884
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.451
# MAPE: 0.116
# r_squared_value: 0.866
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.382
# MAPE: 0.107
# r_squared_value: 0.878
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.124
# MAPE: 0.129
# r_squared_value: 0.883
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.818
# MAPE: 0.126
# r_squared_value: 0.778
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.972
# MAPE: 0.123
# r_squared_value: 0.715
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.9
# MAPE: 0.115
# r_squared_value: 0.725
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.594
# MAPE: 0.125
# r_squared_value: 0.821
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.896
# MAPE: 0.107
# r_squared_value: 0.903
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.522
# MAPE: 0.132
# r_squared_value: 0.882
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.94
# MAPE: 0.11
# r_squared_value: 0.908
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.455
# MAPE: 0.122
# r_squared_value: 0.785
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.617
# MAPE: 0.114
# r_squared_value: 0.845
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.351
# MAPE: 0.121
# r_squared_value: 0.875
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.172
# MAPE: 0.11
# r_squared_value: 0.887
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.918
# MAPE: 0.132
# r_squared_value: 0.832
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.979
# MAPE: 0.118
# r_squared_value: 0.779
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.505
# MAPE: 0.117
# r_squared_value: 0.871
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.054
# MAPE: 0.108
# r_squared_value: 0.865
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.316
# MAPE: 0.127
# r_squared_value: 0.842
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.36
# MAPE: 0.125
# r_squared_value: 0.879
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.748
# MAPE: 0.121
# r_squared_value: 0.823
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.443
# MAPE: 0.123
# r_squared_value: 0.756
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.682
# MAPE: 0.102
# r_squared_value: 0.826
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.203
# MAPE: 0.107
# r_squared_value: 0.86
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.19
# MAPE: 0.112
# r_squared_value: 0.753
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.285
# MAPE: 0.132
# r_squared_value: 0.764
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.403
# MAPE: 0.13
# r_squared_value: 0.858
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.657
# MAPE: 0.122
# r_squared_value: 0.757
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.374
# MAPE: 0.146
# r_squared_value: 0.791
# --------------------------
# training_accuracy: 1.0
# RMSE: 5.033
# MAPE: 0.126
# r_squared_value: 0.746
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.08
# MAPE: 0.128
# r_squared_value: 0.807
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.878
# MAPE: 0.128
# r_squared_value: 0.808
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.451
# MAPE: 0.108
# r_squared_value: 0.868
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.781
# MAPE: 0.112
# r_squared_value: 0.907
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.674
# MAPE: 0.11
# r_squared_value: 0.896
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.41
# MAPE: 0.139
# r_squared_value: 0.864
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.873
# MAPE: 0.139
# r_squared_value: 0.704
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.272
# MAPE: 0.132
# r_squared_value: 0.876
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.772
# MAPE: 0.122
# r_squared_value: 0.806
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.115
# MAPE: 0.111
# r_squared_value: 0.893
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.755
# MAPE: 0.134
# r_squared_value: 0.838
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.013
# MAPE: 0.099
# r_squared_value: 0.866
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.959
# MAPE: 0.106
# r_squared_value: 0.878
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.945
# MAPE: 0.116
# r_squared_value: 0.798
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.295
# MAPE: 0.117
# r_squared_value: 0.869
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.083
# MAPE: 0.125
# r_squared_value: 0.903
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.451
# MAPE: 0.128
# r_squared_value: 0.855
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.151
# MAPE: 0.142
# r_squared_value: 0.833
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.619
# MAPE: 0.127
# r_squared_value: 0.757
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.44
# MAPE: 0.116
# r_squared_value: 0.855
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.399
# MAPE: 0.127
# r_squared_value: 0.799
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.36
# MAPE: 0.117
# r_squared_value: 0.868
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.604
# MAPE: 0.129
# r_squared_value: 0.849
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.817
# MAPE: 0.12
# r_squared_value: 0.849
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.628
# MAPE: 0.126
# r_squared_value: 0.779
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.363
# MAPE: 0.118
# r_squared_value: 0.864
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.014
# MAPE: 0.122
# r_squared_value: 0.856
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.607
# MAPE: 0.113
# r_squared_value: 0.808
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.843
# MAPE: 0.143
# r_squared_value: 0.85
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.684
# MAPE: 0.112
# r_squared_value: 0.845
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.749
# MAPE: 0.138
# r_squared_value: 0.828
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.079
# MAPE: 0.12
# r_squared_value: 0.879
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.639
# MAPE: 0.107
# r_squared_value: 0.903
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.273
# MAPE: 0.126
# r_squared_value: 0.869
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.83
# MAPE: 0.107
# r_squared_value: 0.895
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.543
# MAPE: 0.125
# r_squared_value: 0.861
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.852
# MAPE: 0.104
# r_squared_value: 0.903
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.008
# MAPE: 0.104
# r_squared_value: 0.89
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.989
# MAPE: 0.106
# r_squared_value: 0.886
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.453
# MAPE: 0.129
# r_squared_value: 0.881
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.502
# MAPE: 0.119
# r_squared_value: 0.862
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.974
# MAPE: 0.11
# r_squared_value: 0.904
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.388
# MAPE: 0.1
# r_squared_value: 0.855
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.074
# MAPE: 0.122
# r_squared_value: 0.862
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.471
# MAPE: 0.137
# r_squared_value: 0.835
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.665
# MAPE: 0.113
# r_squared_value: 0.906
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.347
# MAPE: 0.118
# r_squared_value: 0.861
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.789
# MAPE: 0.109
# r_squared_value: 0.811
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.578
# MAPE: 0.115
# r_squared_value: 0.857
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.128
# MAPE: 0.119
# r_squared_value: 0.893
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.283
# MAPE: 0.116
# r_squared_value: 0.884
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.814
# MAPE: 0.121
# r_squared_value: 0.826
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.073
# MAPE: 0.126
# r_squared_value: 0.892
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.013
# MAPE: 0.106
# r_squared_value: 0.885
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.843
# MAPE: 0.092
# r_squared_value: 0.901
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.057
# MAPE: 0.107
# r_squared_value: 0.891
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.544
# MAPE: 0.127
# r_squared_value: 0.832
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.431
# MAPE: 0.131
# r_squared_value: 0.875
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.476
# MAPE: 0.121
# r_squared_value: 0.847
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.43
# MAPE: 0.12
# r_squared_value: 0.853
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.28
# MAPE: 0.105
# r_squared_value: 0.865
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.102
# MAPE: 0.107
# r_squared_value: 0.865
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.63
# MAPE: 0.114
# r_squared_value: 0.842
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.494
# MAPE: 0.11
# r_squared_value: 0.856
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.965
# MAPE: 0.129
# r_squared_value: 0.87
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.296
# MAPE: 0.116
# r_squared_value: 0.873
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.346
# MAPE: 0.117
# r_squared_value: 0.861
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.264
# MAPE: 0.115
# r_squared_value: 0.862
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.086
# MAPE: 0.111
# r_squared_value: 0.888
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.112
# MAPE: 0.1
# r_squared_value: 0.865
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.533
# MAPE: 0.11
# r_squared_value: 0.778
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.6
# MAPE: 0.111
# r_squared_value: 0.834
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.419
# MAPE: 0.129
# r_squared_value: 0.873
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.641
# MAPE: 0.119
# r_squared_value: 0.761
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.297
# MAPE: 0.145
# r_squared_value: 0.764
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.241
# MAPE: 0.129
# r_squared_value: 0.894
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.154
# MAPE: 0.106
# r_squared_value: 0.893
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.589
# MAPE: 0.119
# r_squared_value: 0.867
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.69
# MAPE: 0.12
# r_squared_value: 0.753
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.028
# MAPE: 0.146
# r_squared_value: 0.794
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.202
# MAPE: 0.127
# r_squared_value: 0.778
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.124
# MAPE: 0.107
# r_squared_value: 0.89
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.535
# MAPE: 0.134
# r_squared_value: 0.86
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.807
# MAPE: 0.103
# r_squared_value: 0.905
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.317
# MAPE: 0.113
# r_squared_value: 0.832
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.426
# MAPE: 0.116
# r_squared_value: 0.775
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.15
# MAPE: 0.118
# r_squared_value: 0.873
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.348
# MAPE: 0.104
# r_squared_value: 0.889
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.602
# MAPE: 0.118
# r_squared_value: 0.855
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.875
# MAPE: 0.117
# r_squared_value: 0.899
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.794
# MAPE: 0.131
# r_squared_value: 0.82
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.51
# MAPE: 0.134
# r_squared_value: 0.831
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.053
# MAPE: 0.111
# r_squared_value: 0.871
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.731
# MAPE: 0.106
# r_squared_value: 0.86
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.95
# MAPE: 0.143
# r_squared_value: 0.843
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.047
# MAPE: 0.12
# r_squared_value: 0.898
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.265
# MAPE: 0.132
# r_squared_value: 0.847
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.221
# MAPE: 0.111
# r_squared_value: 0.856
# --------------------------
# training_accuracy: 1.0
# RMSE: 5.007
# MAPE: 0.146
# r_squared_value: 0.761
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.599
# MAPE: 0.119
# r_squared_value: 0.852
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.673
# MAPE: 0.106
# r_squared_value: 0.916
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.911
# MAPE: 0.109
# r_squared_value: 0.883
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.908
# MAPE: 0.11
# r_squared_value: 0.875
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.318
# MAPE: 0.141
# r_squared_value: 0.78
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.29
# MAPE: 0.102
# r_squared_value: 0.882
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.336
# MAPE: 0.115
# r_squared_value: 0.872
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.131
# MAPE: 0.115
# r_squared_value: 0.848
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.702
# MAPE: 0.128
# r_squared_value: 0.841
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.247
# MAPE: 0.126
# r_squared_value: 0.882
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.59
# MAPE: 0.126
# r_squared_value: 0.85
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.617
# MAPE: 0.129
# r_squared_value: 0.856
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.392
# MAPE: 0.11
# r_squared_value: 0.86
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.801
# MAPE: 0.122
# r_squared_value: 0.779
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.301
# MAPE: 0.12
# r_squared_value: 0.886
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.736
# MAPE: 0.123
# r_squared_value: 0.854
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.082
# MAPE: 0.108
# r_squared_value: 0.869
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.049
# MAPE: 0.136
# r_squared_value: 0.775
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.156
# MAPE: 0.121
# r_squared_value: 0.874
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.82
# MAPE: 0.105
# r_squared_value: 0.888
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.691
# MAPE: 0.132
# r_squared_value: 0.836
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.913
# MAPE: 0.099
# r_squared_value: 0.906
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.251
# MAPE: 0.119
# r_squared_value: 0.877
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.701
# MAPE: 0.099
# r_squared_value: 0.898
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.534
# MAPE: 0.106
# r_squared_value: 0.857
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.446
# MAPE: 0.134
# r_squared_value: 0.861
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.298
# MAPE: 0.122
# r_squared_value: 0.836
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.251
# MAPE: 0.121
# r_squared_value: 0.844
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.14
# MAPE: 0.12
# r_squared_value: 0.851
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.939
# MAPE: 0.128
# r_squared_value: 0.85
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.993
# MAPE: 0.113
# r_squared_value: 0.901
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.937
# MAPE: 0.112
# r_squared_value: 0.877
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.047
# MAPE: 0.105
# r_squared_value: 0.858
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.461
# MAPE: 0.118
# r_squared_value: 0.847
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.595
# MAPE: 0.127
# r_squared_value: 0.819
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.031
# MAPE: 0.11
# r_squared_value: 0.817
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.082
# MAPE: 0.121
# r_squared_value: 0.87
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.491
# MAPE: 0.112
# r_squared_value: 0.876
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.243
# MAPE: 0.127
# r_squared_value: 0.87
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.918
# MAPE: 0.131
# r_squared_value: 0.797
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.194
# MAPE: 0.121
# r_squared_value: 0.885
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.691
# MAPE: 0.125
# r_squared_value: 0.837
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.756
# MAPE: 0.101
# r_squared_value: 0.923
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.184
# MAPE: 0.125
# r_squared_value: 0.875
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.644
# MAPE: 0.115
# r_squared_value: 0.839
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.401
# MAPE: 0.127
# r_squared_value: 0.858
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.284
# MAPE: 0.114
# r_squared_value: 0.887
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.99
# MAPE: 0.106
# r_squared_value: 0.87
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.217
# MAPE: 0.117
# r_squared_value: 0.885
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.689
# MAPE: 0.11
# r_squared_value: 0.911
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.622
# MAPE: 0.109
# r_squared_value: 0.84
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.171
# MAPE: 0.111
# r_squared_value: 0.859
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.825
# MAPE: 0.105
# r_squared_value: 0.826
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.614
# MAPE: 0.106
# r_squared_value: 0.917
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.822
# MAPE: 0.115
# r_squared_value: 0.872
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.956
# MAPE: 0.135
# r_squared_value: 0.843
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.427
# MAPE: 0.104
# r_squared_value: 0.87
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.927
# MAPE: 0.099
# r_squared_value: 0.879
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.748
# MAPE: 0.119
# r_squared_value: 0.789
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.016
# MAPE: 0.109
# r_squared_value: 0.849
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.316
# MAPE: 0.127
# r_squared_value: 0.811
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.247
# MAPE: 0.116
# r_squared_value: 0.898
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.626
# MAPE: 0.107
# r_squared_value: 0.871
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.562
# MAPE: 0.123
# r_squared_value: 0.856
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.127
# ...
# RMSE: 3.743
# MAPE: 0.127
# r_squared_value: 0.828
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.026
# MAPE: 0.113
# r_squared_value: 0.88
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.594
# MAPE: 0.127
# r_squared_value: 0.866
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.02
# MAPE: 0.122
# r_squared_value: 0.868
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.806
# MAPE: 0.103
# r_squared_value: 0.905
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.345
# MAPE: 0.118
# r_squared_value: 0.846
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.143
# MAPE: 0.123
# r_squared_value: 0.907
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.828
# MAPE: 0.112
# r_squared_value: 0.885
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.345
# MAPE: 0.1
# r_squared_value: 0.871
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.11
# MAPE: 0.12
# r_squared_value: 0.902
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.303
# MAPE: 0.118
# r_squared_value: 0.866
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.678
# MAPE: 0.138
# r_squared_value: 0.747
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.35
# MAPE: 0.121
# r_squared_value: 0.847
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.2
# MAPE: 0.119
# r_squared_value: 0.895
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.238
# MAPE: 0.125
# r_squared_value: 0.861
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.947
# MAPE: 0.136
# r_squared_value: 0.797
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.523
# MAPE: 0.128
# r_squared_value: 0.863
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.271
# MAPE: 0.118
# r_squared_value: 0.886
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.181
# MAPE: 0.122
# r_squared_value: 0.873
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.441
# MAPE: 0.123
# r_squared_value: 0.864
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.183
# MAPE: 0.105
# r_squared_value: 0.888
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.228
# MAPE: 0.118
# r_squared_value: 0.887
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.284
# MAPE: 0.115
# r_squared_value: 0.873
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.043
# MAPE: 0.111
# r_squared_value: 0.891
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.906
# MAPE: 0.114
# r_squared_value: 0.884
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.507
# MAPE: 0.117
# r_squared_value: 0.835
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.075
# MAPE: 0.121
# r_squared_value: 0.889
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.215
# MAPE: 0.131
# r_squared_value: 0.864
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.32
# MAPE: 0.128
# r_squared_value: 0.877
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.788
# MAPE: 0.135
# r_squared_value: 0.799
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.374
# MAPE: 0.106
# r_squared_value: 0.853
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.527
# MAPE: 0.131
# r_squared_value: 0.865
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.246
# MAPE: 0.108
# r_squared_value: 0.863
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.445
# MAPE: 0.114
# r_squared_value: 0.838
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.758
# MAPE: 0.104
# r_squared_value: 0.91
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.786
# MAPE: 0.114
# r_squared_value: 0.912
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.481
# MAPE: 0.119
# r_squared_value: 0.865
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.191
# MAPE: 0.128
# r_squared_value: 0.877
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.748
# MAPE: 0.117
# r_squared_value: 0.811
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.963
# MAPE: 0.099
# r_squared_value: 0.871
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.727
# MAPE: 0.13
# r_squared_value: 0.872
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.482
# MAPE: 0.122
# r_squared_value: 0.851
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.385
# MAPE: 0.117
# r_squared_value: 0.871
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.168
# MAPE: 0.137
# r_squared_value: 0.785
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.246
# MAPE: 0.122
# r_squared_value: 0.843
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.618
# MAPE: 0.128
# r_squared_value: 0.776
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.014
# MAPE: 0.122
# r_squared_value: 0.845
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.085
# MAPE: 0.101
# r_squared_value: 0.883
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.56
# MAPE: 0.111
# r_squared_value: 0.853
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.272
# MAPE: 0.122
# r_squared_value: 0.857
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.902
# MAPE: 0.107
# r_squared_value: 0.884
# --------------------------
# training_accuracy: 1.0
# RMSE: 5.039
# MAPE: 0.133
# r_squared_value: 0.752
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.341
# MAPE: 0.109
# r_squared_value: 0.858
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.83
# MAPE: 0.137
# r_squared_value: 0.854
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.315
# MAPE: 0.127
# r_squared_value: 0.857
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.566
# MAPE: 0.098
# r_squared_value: 0.931
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.248
# MAPE: 0.119
# r_squared_value: 0.869
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.117
# MAPE: 0.127
# r_squared_value: 0.903
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.328
# MAPE: 0.114
# r_squared_value: 0.863
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.143
# MAPE: 0.129
# r_squared_value: 0.806
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.003
# MAPE: 0.108
# r_squared_value: 0.784
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.34
# MAPE: 0.125
# r_squared_value: 0.777
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.193
# MAPE: 0.126
# r_squared_value: 0.812
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.29
# MAPE: 0.119
# r_squared_value: 0.859
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.591
# MAPE: 0.121
# r_squared_value: 0.85
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.017
# MAPE: 0.128
# r_squared_value: 0.9
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.888
# MAPE: 0.117
# r_squared_value: 0.849
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.212
# MAPE: 0.105
# r_squared_value: 0.867
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.684
# MAPE: 0.09
# r_squared_value: 0.898
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.368
# MAPE: 0.109
# r_squared_value: 0.859
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.575
# MAPE: 0.123
# r_squared_value: 0.858
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.314
# MAPE: 0.116
# r_squared_value: 0.889
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.23
# MAPE: 0.127
# r_squared_value: 0.815
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.213
# MAPE: 0.118
# r_squared_value: 0.888
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.558
# MAPE: 0.114
# r_squared_value: 0.895
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.573
# MAPE: 0.125
# r_squared_value: 0.844
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.451
# MAPE: 0.127
# r_squared_value: 0.871
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.01
# MAPE: 0.119
# r_squared_value: 0.912
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.298
# MAPE: 0.105
# r_squared_value: 0.793
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.643
# MAPE: 0.113
# r_squared_value: 0.863
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.246
# MAPE: 0.112
# r_squared_value: 0.856
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.787
# MAPE: 0.125
# r_squared_value: 0.747
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.326
# MAPE: 0.119
# r_squared_value: 0.871
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.106
# MAPE: 0.117
# r_squared_value: 0.894
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.072
# MAPE: 0.11
# r_squared_value: 0.838
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.975
# MAPE: 0.106
# r_squared_value: 0.885
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.393
# MAPE: 0.117
# r_squared_value: 0.885
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.326
# MAPE: 0.111
# r_squared_value: 0.884
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.917
# MAPE: 0.101
# r_squared_value: 0.84
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.812
# MAPE: 0.114
# r_squared_value: 0.883
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.754
# MAPE: 0.107
# r_squared_value: 0.873
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.564
# MAPE: 0.119
# r_squared_value: 0.785
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.6
# MAPE: 0.138
# r_squared_value: 0.856
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.835
# MAPE: 0.124
# r_squared_value: 0.839
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.365
# MAPE: 0.129
# r_squared_value: 0.797
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.298
# MAPE: 0.123
# r_squared_value: 0.877
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.638
# MAPE: 0.122
# r_squared_value: 0.846
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.086
# MAPE: 0.109
# r_squared_value: 0.817
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.469
# MAPE: 0.102
# r_squared_value: 0.879
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.131
# MAPE: 0.106
# r_squared_value: 0.86
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.745
# MAPE: 0.137
# r_squared_value: 0.854
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.611
# MAPE: 0.128
# r_squared_value: 0.859
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.16
# MAPE: 0.112
# r_squared_value: 0.855
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.168
# MAPE: 0.116
# r_squared_value: 0.849
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.247
# MAPE: 0.114
# r_squared_value: 0.844
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.837
# MAPE: 0.129
# r_squared_value: 0.848
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.624
# MAPE: 0.103
# r_squared_value: 0.858
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.945
# MAPE: 0.111
# r_squared_value: 0.909
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.727
# MAPE: 0.109
# r_squared_value: 0.906
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.351
# MAPE: 0.126
# r_squared_value: 0.857
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.156
# MAPE: 0.123
# r_squared_value: 0.834
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.3
# MAPE: 0.122
# r_squared_value: 0.877
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.034
# MAPE: 0.106
# r_squared_value: 0.892
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.933
# MAPE: 0.122
# r_squared_value: 0.83
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.519
# MAPE: 0.132
# r_squared_value: 0.809
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.213
# MAPE: 0.125
# r_squared_value: 0.848
# --------------------------
# training_accuracy: 1.0
# RMSE: 2.884
# MAPE: 0.106
# r_squared_value: 0.903
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.415
# MAPE: 0.127
# r_squared_value: 0.841
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.346
# MAPE: 0.115
# r_squared_value: 0.869
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.2
# MAPE: 0.11
# r_squared_value: 0.835
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.143
# MAPE: 0.11
# r_squared_value: 0.9
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.622
# MAPE: 0.113
# r_squared_value: 0.852
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.929
# MAPE: 0.121
# r_squared_value: 0.813
# --------------------------
# training_accuracy: 1.0
# RMSE: 5.126
# MAPE: 0.166
# r_squared_value: 0.734
# --------------------------
# training_accuracy: 1.0
# RMSE: 4.313
# MAPE: 0.131
# r_squared_value: 0.797
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.096
# MAPE: 0.119
# r_squared_value: 0.889
# --------------------------
# training_accuracy: 1.0
# RMSE: 3.06
# MAPE: 0.105
# r_squared_value: 0.89
# --------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16800\1248106150.py in <module>
#       8     X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3, random_state=i)
#       9     xgbrModel=xgb.XGBRegressor()
# ---> 10     xgbrModel.fit(X_train,y_train)
#      11     print(f'training_accuracy: {round(xgbrModel.score(X_train, y_train),3)}')
#      12
#
# c:\Users\mb207\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py in inner_f(*args, **kwargs)
#     573         for k, arg in zip(sig.parameters, args):
#     574             kwargs[k] = arg
# --> 575         return f(**kwargs)
#     576
#     577     return inner_f
#
# c:\Users\mb207\anaconda3\envs\myenv\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     970             verbose_eval=verbose,
#     971             xgb_model=model,
# --> 972             callbacks=callbacks,
#     973         )
#     974
#
# c:\Users\mb207\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py in inner_f(*args, **kwargs)
#     573         for k, arg in zip(sig.parameters, args):
#     574             kwargs[k] = arg
# --> 575         return f(**kwargs)
#     576
#     577     return inner_f
#
# c:\Users\mb207\anaconda3\envs\myenv\lib\site-packages\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     190     # Copy to serialise and unserialise booster to reset state and free
#     191     # training memory
# --> 192     return bst.copy()
#     193
#     194
#
# c:\Users\mb207\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py in copy(self)
#    1623             a copied booster model
#    1624         """
# -> 1625         return copy.copy(self)
#    1626
#    1627     def attr(self, key: str) -> Optional[str]:
#
# c:\Users\mb207\anaconda3\envs\myenv\lib\copy.py in copy(x)
#      86     copier = getattr(cls, "__copy__", None)
#      87     if copier:
# ---> 88         return copier(x)
#      89
#      90     reductor = dispatch_table.get(cls)
#
# c:\Users\mb207\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py in __copy__(self)
#    1609
#    1610     def __copy__(self) -> "Booster":
# -> 1611         return self.__deepcopy__(None)
#    1612
#    1613     def __deepcopy__(self, _: Any) -> "Booster":
#
# c:\Users\mb207\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py in __deepcopy__(self, _)
#    1613     def __deepcopy__(self, _: Any) -> "Booster":
#    1614         '''Return a copy of booster.'''
# -> 1615         return Booster(model_file=self)
#    1616
#    1617     def copy(self) -> "Booster":
#
# c:\Users\mb207\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py in __init__(self, params, cache, model_file)
#    1420             # We use the pickle interface for getting memory snapshot from
#    1421             # another model, and load the snapshot with this booster.
# -> 1422             state = model_file.__getstate__()
#    1423             handle = state['handle']
#    1424             del state['handle']
#
# c:\Users\mb207\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py in __getstate__(self)
#    1523             _check_call(_LIB.XGBoosterSerializeToBuffer(self.handle,
#    1524                                                         ctypes.byref(length),
# -> 1525                                                         ctypes.byref(cptr)))
#    1526             buf = ctypes2buffer(cptr, length.value)
#    1527             this["handle"] = buf
#
# KeyboardInterrupt:

# %%
import xgboost as xgb
for i in range(1,11,1):
   # 建立 XGBRegressor 模型
   xgbrModel=xgb.XGBRegressor(max_depth=i,random_state=0,verbosity=2)
   # 使用訓練資料訓練模型
   xgbrModel.fit(X_train,y_train)
   acc = xgbrModel.score(X_train.values, y_train)
   print(f'分類器準確度: {round(acc,3)}') 
   # 使用訓練資料                               
   pred=xgbrModel.predict(X_test)
   #calculate RMSE argument If True returns MSE value, if False returns RMSE value.
   #calculate rmse
   error_rmse = mean_squared_error(y_test,pred,squared=False) 
   print('RMSE value for max_depth= ' , i , 'is:', round(error_rmse,3))
   #calculate mape
   error_mape = mean_absolute_percentage_error(y_test,pred) 
   print('MAPE value for max_depth= ' , i , 'is:', round(error_mape,3))
   #calculate r squared
   error_r2 = r2_score(y_test,pred) 
   print('MAPE value for max_depth= ' , i , 'is:', round(error_r2,3))

# %%
# plotting the y_test vs y_pred
plt.scatter(y_pred,y_test)
plt.xlabel('y_pred')
plt.ylabel('y_test')
plt.show()

# %%
act_y =[round(i,1) for i in y_test.values]
pre_y =y_pred
plt.plot(pre_y, label='predict value',color='red')
plt.plot(act_y, label='true value',color='blue')
plt.ylabel("y")
plt.xlabel("X")
plt.title("predict of Y")
plt.xlim([0, 170])
plt.grid(True)
plt.legend()
plt.show()

# %%
xfeatures=list(X_train.columns[:])  
importances = list(xgbrModel.feature_importances_)
df_importance = pd.DataFrame({'feature':xfeatures,'feature_importance':importances})
df_importance = df_importance.sort_values(by=['feature_importance'],ascending=False).reset_index(drop=True)
print("每個特徵值的重要性：")
print(df_importance.loc[df_importance['feature_importance']!=0])
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16800\2370936028.py in <module>
#       1 xfeatures=list(X_train.columns[:])
# ----> 2 importances = list(xgbrModel.feature_importances_)
#       3 df_importance = pd.DataFrame({'feature':xfeatures,'feature_importance':importances})
#       4 df_importance = df_importance.sort_values(by=['feature_importance'],ascending=False).reset_index(drop=True)
#       5 print("每個特徵值的重要性：")
#
# c:\Users\mb207\anaconda3\envs\myenv\lib\site-packages\xgboost\sklearn.py in feature_importances_(self)
#    1199
#    1200         """
# -> 1201         b: Booster = self.get_booster()
#    1202
#    1203         def dft() -> str:
#
# c:\Users\mb207\anaconda3\envs\myenv\lib\site-packages\xgboost\sklearn.py in get_booster(self)
#     588         if not self.__sklearn_is_fitted__():
#     589             from sklearn.exceptions import NotFittedError
# --> 590             raise NotFittedError('need to call fit or load_model beforehand')
#     591         return self._Booster
#     592
#
# NotFittedError: need to call fit or load_model beforehand

# %%
#以圖表事每個特徵變數的重要程度(0最小，1最大)
def plot_feature_importances_cancer(model):
    n_features = X_train.shape[1]
    plt.figure(figsize=(12,8))
    plt.barh(np.arange(n_features), model.feature_importances_, align='center')
    plt.yticks(np.arange(n_features), X_train.columns)
    plt.xlabel("Feature importance")
    plt.ylabel("Feature")
    plt.ylim(-1, n_features)

plot_feature_importances_cancer(xgbrModel)
